# %% [markdown]
# # Deploy on Web

# %%
pip install flask-ngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/Project_snake
# Out:
# /content/drive/MyDrive/Colab Notebooks/Project_snake

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import pickle
import numpy as np

# %%
# !pip install pyngrok

# %%
# !ngrok authtoken 2dZs4I3eCeZS6q7As54SqXjNeJl_3NahpC911Rm5wMgTPmLoX
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import numpy as np
from flask import Flask, render_template, request
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from pyngrok import ngrok

app = Flask(__name__)
run_with_ngrok(app)

model = load_model('/content/drive/MyDrive/Colab Notebooks/Project_snake/snake_model.h5')
model.make_predict_function()

ngrok_tunnel = ngrok.connect(5000)
print('Public URL:', ngrok_tunnel.public_url)

def predict_label(img_path):
    i = load_img(img_path, target_size=(128, 128))
    i = img_to_array(i) / 255.0
    i = i.reshape(1, 128, 128, 3)

    p = model.predict(i)
    text = []
    if p < 0.5:
        p[0][0] *= 1000
        txt = 'Non Venomous'
    else:
        p[0][0] *= 100
        txt = 'Venomous'
    pre = '%.2f' % p[0][0]
    return pre, txt

@app.route("/", methods=['GET', 'POST'])
def main():
    return render_template("index3.html")

@app.route("/about")
def about_page():
    return "Please subscribe Artificial Intelligence Hub..!!!"

@app.route("/submit", methods=['GET', 'POST'])
def get_output():
    if request.method == 'POST':
        img = request.files['my_image']
        img_path = "static/" + img.filename
        img.save(img_path)
        p1 = predict_label(img_path)
    return render_template("index3.html", prediction=p1[0], TEXT=p1[1], img_path=img_path)

app.run()
# Out:
# Public URL: https://3587-34-91-5-208.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://3587-34-91-5-208.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [23/Mar/2024 16:54:29] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Mar/2024 16:54:29] "GET /favicon.ico HTTP/1.1" 404 -
# ...
